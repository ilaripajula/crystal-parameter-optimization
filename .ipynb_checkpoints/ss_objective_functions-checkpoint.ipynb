# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ss_curves.csv')

# %%
def preprocess(df):
    stress = np.array([df[col] for col in df.columns if "stress" in col])
    strain = np.array([df[col] for col in df.columns if "strain" in col])
    labels = ["Experimental"] + [f"Simulated {i}" for i in range(1, len(stress))]

    # Cut the excess values above and below the experimental values.
    y_min, y_max = stress[0].min(), stress[0].max()
    x_min, x_max = strain[0].min(), strain[0].max()
    
    
    return stress, strain, labels


def plot(stress, strain, label):
    plt.figure(figsize=(20,12))
    for x,y,label in zip(strain,stress,label):
        plt.plot(x, y, label=label)
    plt.xlim([0,0.1])
    plt.ylim([900,1100])
    plt.vlines(strain[0].max(), 0, 1100, linestyle='dotted')
    plt.legend()
    plt.show()

# %%
stress, strain, labels = preprocess(df)

# %%
plot(stress, strain, labels)

# %% [markdown]
# #### Largest change in experimental strain is always 1.64e-4 while simulated change in strain always 2e-4

# %%
delta_strain= np.concatenate(([0],strain[0,:-1])) - strain[0]
plt.plot(range(len(strain[0])),delta_strain)
print(np.abs(delta_strain).max())
# Out:
# 0.00016409199999999763

# %% [markdown]
# #### Rounding to 3 decimals would mean that we do not have to interpolate

# %%
exp_strain = np.around(strain[0], decimals=4)
sim_strain = np.around(strain[1], decimals=4)
max_strain = exp_strain.max()

# %%
for x in sim_strain:
    if x < max_strain:
        if x not in exp_strain:
            print("NOOO", exp_strain, x)
# Out:
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.028
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0452
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0454
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0512
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.052
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0544
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0558
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0576
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0578
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.059
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0606
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0612
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0622
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0632
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0642
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0646
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0664
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0668
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0672
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0676
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.0688
# NOOO [0.     0.     0.     ... 0.0706 0.0707 0.0708] 0.069
